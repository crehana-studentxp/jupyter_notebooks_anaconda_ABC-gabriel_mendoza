# %% [markdown]
# # Gráfico de Dispersión

# %% [markdown]
# ### Importamos la base

# %%
import pandas as pd
import numpy as np

# %%
path='C:\\Users\\Gabo\\Documents\\Gabriel Mendoza\\Business\\Crehana\\El ABC de Jupyter Notebook y Anaconda\\Material\\04 Módulo 4\\Clase 17\\Facturación.xlsx'

# %%
df=pd.read_excel(path)

# %%
df
# Out:
#       Factura Fecha de Emision Fecha de Pago  No. cliente      Cliente  \
# 0    FACT2000       2020-01-06    2020-01-30          208  CC208208208
# 1    FACT2001       2020-01-07    2020-02-19           45     CC454545
# 2    FACT2002       2020-01-08    2020-02-17          268  CC268268268
# 3    FACT2003       2020-01-08    2020-02-07          157  CC157157157
# 4    FACT2004       2020-01-09           NaT          157  CC157157157
# ..        ...              ...           ...          ...          ...
# 504  FACT2550       2020-06-05    2020-06-02          159  CC159159159
# 505  FACT2551       2020-06-12    2020-06-15          176  CC176176176
# 506  FACT2552       2020-06-18    2020-06-22          305  CC305305305
# 507  FACT2553       2020-06-19    2020-06-18          305  CC305305305
# 508  FACT2554       2020-06-30    2020-06-29          209  CC209209209
#
#     Vendedor        Costo  Importe Factura  Importe Pagado  \
# ...

# %% [markdown]
# #### Objetivo: graficar el porcentaje de utilidad vs el importe pagado por vendedor

# %% [markdown]
# ### Primero se prepara la base de datos

# %%
# Calculamos la utilidad
# Out:
#       Factura Fecha de Emision Fecha de Pago  No. cliente      Cliente  \
# 0    FACT2000       2020-01-06    2020-01-30          208  CC208208208
# 1    FACT2001       2020-01-07    2020-02-19           45     CC454545
# 2    FACT2002       2020-01-08    2020-02-17          268  CC268268268
# 3    FACT2003       2020-01-08    2020-02-07          157  CC157157157
# 4    FACT2004       2020-01-09           NaT          157  CC157157157
# ..        ...              ...           ...          ...          ...
# 504  FACT2550       2020-06-05    2020-06-02          159  CC159159159
# 505  FACT2551       2020-06-12    2020-06-15          176  CC176176176
# 506  FACT2552       2020-06-18    2020-06-22          305  CC305305305
# 507  FACT2553       2020-06-19    2020-06-18          305  CC305305305
# 508  FACT2554       2020-06-30    2020-06-29          209  CC209209209
#
#     Vendedor        Costo  Importe Factura  Importe Pagado  \
# ...

# %%
# Out:
# <ipython-input-19-ba8ba0d52e25>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df=df.groupby(['Mes','Vendedor'],as_index=False)['Importe Pagado','Utilidad'].sum()
#     Mes Vendedor  Importe Pagado     Utilidad
# 0   1.0     Bety      987.991025   157.225288
# 1   1.0  Claudia      411.126820    87.705487
# 2   1.0     Juan      218.825386    55.737608
# 3   2.0     Bety     6547.432995   973.808149
# 4   2.0  Claudia      839.304215   104.439659
# 5   2.0     Juan     9200.883575   480.235279
# 6   3.0     Bety    16363.359105  4156.558597
# 7   3.0  Claudia    20436.572768  4453.436405
# 8   3.0     Juan     5364.761867  1981.385867
# 9   4.0     Bety    10734.524488  2721.839350
# 10  4.0  Claudia    34145.253625  6947.458092
# 11  4.0     Juan     7385.276076  3227.513065
# 12  5.0     Bety     8722.987703  2731.022531
# 13  5.0  Claudia    19025.749057  3152.945380
# ...

# %% [markdown]
# ### Gráfico de dispersión

# %%
# %matplotlib inline 

import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# Grafiquemos la data. En `Matplotlib`, podemos crear un `scatter` plot o gráfico de dispersión indicando `kind='scatter'` como el argumento del gráfico. También necesitaremos indicarle  nuestra `x` y `y` especificando las columns que van en la x y y.

# %%
#Agregamos legendas

# %%
plt.scatter(df_juan['Importe Pagado'],df_juan['Utilidad'],color='Blue',label='Juan')
plt.scatter(df_clau['Importe Pagado'],df_clau['Utilidad'],color='Red',label='Claudia')
plt.scatter(df_bety['Importe Pagado'],df_bety['Utilidad'],color='Yellow',label='Bety')
plt.xlabel('Importe Pagado')
plt.ylabel('Utilidad')
plt.legend()
